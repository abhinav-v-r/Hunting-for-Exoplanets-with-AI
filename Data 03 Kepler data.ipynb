# %% [raw]
# # This file was produced by the NASA Exoplanet Archive  http://exoplanetarchive.ipac.caltech.edu
# # Tue Sep 30 00:31:11 2025
# #
# # COLUMN kepid:          KepID
# # COLUMN kepoi_name:     KOI Name
# # COLUMN kepler_name:    Kepler Name
# # COLUMN koi_disposition: Exoplanet Archive Disposition
# # COLUMN koi_pdisposition: Disposition Using Kepler Data
# # COLUMN koi_score:      Disposition Score
# # COLUMN koi_fpflag_nt:  Not Transit-Like False Positive Flag
# # COLUMN koi_fpflag_ss:  Stellar Eclipse False Positive Flag
# # COLUMN koi_fpflag_co:  Centroid Offset False Positive Flag
# # COLUMN koi_fpflag_ec:  Ephemeris Match Indicates Contamination False Positive Flag
# # COLUMN koi_period:     Orbital Period [days]
# # COLUMN koi_period_err1: Orbital Period Upper Unc. [days]
# # COLUMN koi_period_err2: Orbital Period Lower Unc. [days]
# # COLUMN koi_time0bk:    Transit Epoch [BKJD]
# # COLUMN koi_time0bk_err1: Transit Epoch Upper Unc. [BKJD]
# # COLUMN koi_time0bk_err2: Transit Epoch Lower Unc. [BKJD]
# # COLUMN koi_impact:     Impact Parameter
# # COLUMN koi_impact_err1: Impact Parameter Upper Unc.
# # COLUMN koi_impact_err2: Impact Parameter Lower Unc.
# # COLUMN koi_duration:   Transit Duration [hrs]
# # COLUMN koi_duration_err1: Transit Duration Upper Unc. [hrs]
# # COLUMN koi_duration_err2: Transit Duration Lower Unc. [hrs]
# # COLUMN koi_depth:      Transit Depth [ppm]
# # COLUMN koi_depth_err1: Transit Depth Upper Unc. [ppm]
# # COLUMN koi_depth_err2: Transit Depth Lower Unc. [ppm]
# # COLUMN koi_prad:       Planetary Radius [Earth radii]
# # COLUMN koi_prad_err1:  Planetary Radius Upper Unc. [Earth radii]
# # COLUMN koi_prad_err2:  Planetary Radius Lower Unc. [Earth radii]
# # COLUMN koi_teq:        Equilibrium Temperature [K]
# # COLUMN koi_teq_err1:   Equilibrium Temperature Upper Unc. [K]
# # COLUMN koi_teq_err2:   Equilibrium Temperature Lower Unc. [K]
# # COLUMN koi_insol:      Insolation Flux [Earth flux]
# # COLUMN koi_insol_err1: Insolation Flux Upper Unc. [Earth flux]
# # COLUMN koi_insol_err2: Insolation Flux Lower Unc. [Earth flux]
# # COLUMN koi_model_snr:  Transit Signal-to-Noise
# # COLUMN koi_tce_plnt_num: TCE Planet Number
# # COLUMN koi_tce_delivname: TCE Delivery
# # COLUMN koi_steff:      Stellar Effective Temperature [K]
# # COLUMN koi_steff_err1: Stellar Effective Temperature Upper Unc. [K]
# # COLUMN koi_steff_err2: Stellar Effective Temperature Lower Unc. [K]
# # COLUMN koi_slogg:      Stellar Surface Gravity [log10(cm/s**2)]
# # COLUMN koi_slogg_err1: Stellar Surface Gravity Upper Unc. [log10(cm/s**2)]
# # COLUMN koi_slogg_err2: Stellar Surface Gravity Lower Unc. [log10(cm/s**2)]
# # COLUMN koi_srad:       Stellar Radius [Solar radii]
# # COLUMN koi_srad_err1:  Stellar Radius Upper Unc. [Solar radii]
# # COLUMN koi_srad_err2:  Stellar Radius Lower Unc. [Solar radii]
# # COLUMN ra:             RA [decimal degrees]
# # COLUMN dec:            Dec [decimal degrees]
# # COLUMN koi_kepmag:     Kepler-band [mag]
# #

# %%
import pandas as pd

# %%
df = pd.read_excel(r"D:\Additional\Data 03.xlsx")

# %%
df.head()
# Out:
#       kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2  10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  ...  \
# 0      1.000              0              0              0              0  ...
# 1      0.969              0              0              0              0  ...
# 2      0.000              0              0              0              0  ...
# 3      0.000              0              1              0              0  ...
# 4      1.000              0              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
unrelated_features = [ 'kepid', 'kepoi_name', 
                       'kepler_name', 'koi_disposition', 'koi_insol', 
                       'koi_insol_err1', 'koi_insol_err2', 'koi_slogg', 
                       'koi_slogg_err1', 'koi_slogg_err2', 'koi_fpflag_ec',
                      'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_tce_delivname']
data = df.drop(unrelated_features, axis=1)

# %%
data.head()
# Out:
#   koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0        CANDIDATE      1.000              0              0              0
# 1        CANDIDATE      0.969              0              0              0
# 2        CANDIDATE      0.000              0              0              0
# 3   FALSE POSITIVE      0.000              0              1              0
# 4        CANDIDATE      1.000              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0    9.488036     2.775000e-05    -2.775000e-05   170.538750
# 1   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 2   19.899140     1.494000e-05    -1.494000e-05   175.850252
# 3    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4    2.525592     3.761000e-06    -3.761000e-06   171.595550
#
#    koi_time0bk_err1  ...  koi_tce_plnt_num  koi_steff  koi_steff_err1  \
# 0          0.002160  ...               1.0     5455.0            81.0
# ...

# %%
#DepVariable
#data = data.drop('koi_pdisposition', axis=1)

# %%
print(data.columns.tolist())
# Out:
# ['koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_period', 'koi_period_err1', 'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2', 'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2', 'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2', 'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag']

# %%
# Set options to display all rows and all columns
#pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
data.head()
# Out:
#   koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0        CANDIDATE      1.000              0              0              0
# 1        CANDIDATE      0.969              0              0              0
# 2        CANDIDATE      0.000              0              0              0
# 3   FALSE POSITIVE      0.000              0              1              0
# 4        CANDIDATE      1.000              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0    9.488036     2.775000e-05    -2.775000e-05   170.538750
# 1   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 2   19.899140     1.494000e-05    -1.494000e-05   175.850252
# 3    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4    2.525592     3.761000e-06    -3.761000e-06   171.595550
#
#    koi_time0bk_err1  koi_time0bk_err2  koi_impact  koi_impact_err1  \
# 0          0.002160         -0.002160       0.146            0.318
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['koi_pdisposition'] = le.fit_transform(data['koi_pdisposition'])

# %%
data.isnull().any()
# Out:
# koi_pdisposition     False
# koi_score             True
# koi_fpflag_nt        False
# koi_fpflag_ss        False
# koi_fpflag_co        False
# koi_period           False
# koi_period_err1       True
# koi_period_err2       True
# koi_time0bk          False
# koi_time0bk_err1      True
# koi_time0bk_err2      True
# koi_impact            True
# koi_impact_err1       True
# koi_impact_err2       True
# koi_duration         False
# koi_duration_err1     True
# koi_duration_err2     True
# koi_depth             True
# koi_depth_err1        True
# koi_depth_err2        True
# koi_prad              True
# koi_prad_err1         True
# koi_prad_err2         True
# koi_model_snr         True
# koi_tce_plnt_num      True
# koi_steff             True
# koi_steff_err1        True
# koi_steff_err2        True
# koi_srad              True
# koi_srad_err1         True
# koi_srad_err2         True
# ra                   False
# dec                  False
# koi_kepmag            True
# dtype: bool

# %%
len(data.columns[data.isnull().any()])
# 2. Use this list to select and print the columns from the DataFrame
#data[columns_with_nan]
# Out:
# 25

# %%
rows_with_nan = data[data.isnull().any(axis=1)]
#print("\nRows containing at least one NaN value:")
rows_with_nan
# Out:
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 24                   1        NaN              0              1
# 75                   1        NaN              0              0
# 99                   0        NaN              0              0
# 123                  0        NaN              0              0
# 143                  0      1.000              0              0
# ...                ...        ...            ...            ...
# 9440                 1      0.000              0              1
# 9501                 1      0.207              1              0
# 9517                 0      0.000              0              0
# 9535                 1      0.116              1              0
# 9553                 1      0.024              1              0
#
#       koi_fpflag_co  koi_period  koi_period_err1  koi_period_err2  \
# 24                0  386.603053     1.369000e-04    -1.369000e-04
# ...

# %%
import numpy as np
# Check for infinite values
print((data == np.inf).sum())
# Out:
# koi_pdisposition     0
# koi_score            0
# koi_fpflag_nt        0
# koi_fpflag_ss        0
# koi_fpflag_co        0
# koi_period           0
# koi_period_err1      0
# koi_period_err2      0
# koi_time0bk          0
# koi_time0bk_err1     0
# koi_time0bk_err2     0
# koi_impact           0
# koi_impact_err1      0
# koi_impact_err2      0
# koi_duration         0
# koi_duration_err1    0
# koi_duration_err2    0
# koi_depth            0
# koi_depth_err1       0
# koi_depth_err2       0
# koi_prad             0
# koi_prad_err1        0
# koi_prad_err2        0
# koi_model_snr        0
# koi_tce_plnt_num     0
# koi_steff            0
# koi_steff_err1       0
# koi_steff_err2       0
# koi_srad             0
# koi_srad_err1        0
# koi_srad_err2        0
# ra                   0
# dec                  0
# koi_kepmag           0
# dtype: int64

# %%
data.isnull().any(axis=1).sum()
# Out:
# 1761

# %%
# Creates a new DataFrame and assigns it to 'data'
data = data.dropna(axis=0)

# %%
data
# Out:
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0                    0      1.000              0              0
# 1                    0      0.969              0              0
# 2                    0      0.000              0              0
# 3                    1      0.000              0              1
# 4                    0      1.000              0              0
# ...                ...        ...            ...            ...
# 9559                 1      0.000              0              1
# 9560                 0      0.497              0              0
# 9561                 1      0.021              0              0
# 9562                 0      0.092              0              0
# 9563                 1      0.000              0              0
#
#       koi_fpflag_co  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0    9.488036     2.775000e-05    -2.775000e-05
# ...

# %%
# Set the option to display all rows
pd.set_option('display.max_rows', None)

print("\nComplete Full Output:")
print(data.nunique())

# It's good practice to reset the option afterward
pd.reset_option('display.max_rows')
# Out:
# Complete Full Output:
# koi_pdisposition        2
# koi_score             642
# koi_fpflag_nt           3
# koi_fpflag_ss           2
# koi_fpflag_co           2
# koi_period           7803
# koi_period_err1      6376
# koi_period_err2      6376
# koi_time0bk          7787
# koi_time0bk_err1     2365
# koi_time0bk_err2     2365
# koi_impact           1378
# koi_impact_err1      1244
# koi_impact_err2       867
# koi_duration         6781
# koi_duration_err1    2142
# koi_duration_err2    2142
# koi_depth            6196
# koi_depth_err1       1303
# koi_depth_err2       1303
# koi_prad             2753
# koi_prad_err1        1694
# koi_prad_err2        1479
# koi_model_snr        2608
# koi_tce_plnt_num        8
# koi_steff            2265
# koi_steff_err1        258
# koi_steff_err2        358
# koi_srad             2051
# koi_srad_err1         925
# koi_srad_err2        1215
# ra                   6650
# dec                  6682
# koi_kepmag           3455
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,15))
sns.heatmap(data .corr(),annot=True, cmap="Reds",linewidth=0.5)
plt.show()

# %%
corr =data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_4b18e_row0_col0, #T_4b18e_row1_col1, #T_4b18e_row2_col2, #T_4b18e_row3_col3, #T_4b18e_row4_col4, #T_4b18e_row5_col5, #T_4b18e_row6_col6, #T_4b18e_row7_col7, #T_4b18e_row8_col8, #T_4b18e_row9_col9, #T_4b18e_row10_col10, #T_4b18e_row11_col11, #T_4b18e_row12_col12, #T_4b18e_row13_col13, #T_4b18e_row14_col14, #T_4b18e_row15_col15, #T_4b18e_row16_col16, #T_4b18e_row17_col17, #T_4b18e_row18_col18, #T_4b18e_row19_col19, #T_4b18e_row20_col20, #T_4b18e_row21_col21, #T_4b18e_row22_col22, #T_4b18e_row23_col23, #T_4b18e_row24_col24, #T_4b18e_row25_col25, #T_4b18e_row26_col26, #T_4b18e_row27_col27, #T_4b18e_row28_col28, #T_4b18e_row29_col29, #T_4b18e_row30_col30, #T_4b18e_row31_col31, #T_4b18e_row32_col32, #T_4b18e_row33_col33 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# ...

# %%
#df.to_csv('my_full_dataset.csv', index=False)

# %%
#print(data.head(0))

# %% [raw]
# Here we use the target column as COLUMN koi_pdisposition: Disposition Using Kepler and we remove the  column COLUMN koi_disposition: Exoplanet Archive Disposition

# %% [markdown]
# Train Test Split - data

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(columns = ['koi_pdisposition'])
Y = data['koi_pdisposition']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25)

# %%
print("Train Shape",X_train.shape)
print("Test Shape",X_test.shape)
# Out:
# Train Shape (5852, 33)
# Test Shape (1951, 33)

# %% [markdown]
# Models

# %%
from sklearn import metrics

# %% [markdown]
# Logistic Regression model using data

# %%
from sklearn.linear_model import LogisticRegression
#model= LogisticRegression(solver='lbfgs')
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediction=model.predict(X_test)
prediction
# Out:
# array([1, 0, 0, ..., 0, 1, 1])

# %%
Logi_acc=metrics.accuracy_score(prediction,Y_test)*100
print('The accuracy of the LogisticRegression is',round(Logi_acc,2))
# Out:
# The accuracy of the LogisticRegression is 76.37

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(Y_test,prediction)
print(cm)
# Out:
# [[864 156]
#  [305 626]]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ax=plt.axes()
data_cm=cm
sns.heatmap(data_cm,annot=True,annot_kws={"size": 30}, fmt='d',cmap="Blues", ax = ax )
ax.set_title('Confusion Matrix')
plt.show()

# %% [markdown]
# Decision Tree model using data

# %%
from sklearn.tree import DecisionTreeClassifier
mymodel=DecisionTreeClassifier()
mymodel.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction=mymodel.predict(X_test)
prediction
# Out:
# array([0, 0, 0, ..., 1, 1, 0])

# %%
Dec_acc=metrics.accuracy_score(prediction,Y_test)*100
print('The accuracy of the Decision Tree is',round(Dec_acc,2))
# Out:
# The accuracy of the Decision Tree is 99.28

# %% [markdown]
# KNeighborsClassifier using data

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
import numpy as np
error_rate = []
for i in range(1,80):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,Y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != Y_test))

plt.figure(figsize=(5,15))
plt.plot(range(1,80),error_rate,color='blue', linestyle='dashed',
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
print("Minimum error:-",min(error_rate),"at K =",error_rate.index(min(error_rate)))
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Create a scaler object
scaler = StandardScaler()
data1 = data.drop('koi_pdisposition',axis = 1)
# Fit and transform the data
scaled_data = scaler.fit_transform(data1)

# %%
# Create a PCA instance with 2 components
pca = PCA(n_components=17)

# Fit and transform the scaled data to get the principal components
principal_components = pca.fit_transform(scaled_data)

# Create a new DataFrame with the principal components
pca_data = pd.DataFrame(data = principal_components)

# %%
print(f"Variance explained by PC1: {pca.explained_variance_ratio_[0]:.2%}")
print(f"Variance explained by PC2: {pca.explained_variance_ratio_[1]:.2%}")
print(f"Variance explained by PC3: {pca.explained_variance_ratio_[2]:.2%}")
print(f"Variance explained by PC4: {pca.explained_variance_ratio_[3]:.2%}")
print(f"Variance explained by PC5: {pca.explained_variance_ratio_[4]:.2%}")
print(f"Variance explained by PC6: {pca.explained_variance_ratio_[5]:.2%}")
print(f"Variance explained by PC7: {pca.explained_variance_ratio_[6]:.2%}")
print(f"Variance explained by PC8: {pca.explained_variance_ratio_[7]:.2%}")
print(f"Variance explained by PC9: {pca.explained_variance_ratio_[8]:.2%}")
print(f"Variance explained by PC10: {pca.explained_variance_ratio_[9]:.2%}")
print(f"Variance explained by PC11: {pca.explained_variance_ratio_[10]:.2%}")
print(f"Variance explained by PC12: {pca.explained_variance_ratio_[11]:.2%}")
print(f"Variance explained by PC13: {pca.explained_variance_ratio_[12]:.2%}")
print(f"Variance explained by PC14: {pca.explained_variance_ratio_[13]:.2%}")
print(f"Variance explained by PC15: {pca.explained_variance_ratio_[14]:.2%}")
print(f"Variance explained by PC16: {pca.explained_variance_ratio_[15]:.2%}")
print(f"Variance explained by PC17: {pca.explained_variance_ratio_[16]:.2%}")
#print(f"Variance explained by PC18: {pca.explained_variance_ratio_[17]:.2%}")
#print(f"Variance explained by PC2: {pca.explained_variance_ratio_[18]:.2%}")
print(f"Total variance explained by both: {pca.explained_variance_ratio_.sum():.2%}")
# Out:
# Variance explained by PC1: 14.29%
# Variance explained by PC2: 11.75%
# Variance explained by PC3: 9.41%
# Variance explained by PC4: 7.68%
# Variance explained by PC5: 6.59%
# Variance explained by PC6: 5.54%
# Variance explained by PC7: 5.11%
# Variance explained by PC8: 4.26%
# Variance explained by PC9: 3.93%
# Variance explained by PC10: 3.20%
# Variance explained by PC11: 3.05%
# Variance explained by PC12: 2.91%
# Variance explained by PC13: 2.82%
# Variance explained by PC14: 2.75%
# Variance explained by PC15: 2.62%
# Variance explained by PC16: 2.43%
# Variance explained by PC17: 1.85%
# Total variance explained by both: 90.18%

# %%
# 4. Create and display the scree plot
explained_variance = pca.explained_variance_ratio_
n_components = np.arange(1, len(explained_variance) + 1)

plt.figure(figsize=(10, 7))
plt.plot(n_components, explained_variance, 'o-', linewidth=2, color='blue')
plt.title('Scree Plot for PCA')
plt.xlabel('Number of Principal Components')
plt.ylabel('Proportion of Variance Explained')
plt.grid()
plt.show()

# %%
pca_data
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.696176 -1.707054  1.134817 -0.429099  0.854193 -0.196629  0.173733
# 1    -0.335376 -1.606863  1.461776 -0.674620  0.833702 -0.165504 -0.260087
# 2    -0.685614  0.356145 -0.468590 -0.450091 -0.063776  0.244011 -0.311701
# 3    -1.107104  0.677089 -0.617971 -0.432167 -0.069818 -0.546153 -0.318043
# 4    -0.738158 -0.611929  0.159065 -0.522251 -0.404564 -0.035787  0.410699
# ...        ...       ...       ...       ...       ...       ...       ...
# 7798 -1.239408  0.971100 -0.788529  0.262731 -1.176297  0.095130 -0.486601
# 7799 -0.290698 -0.571191 -0.355677  0.020655 -0.285682  0.152356  1.247329
# 7800 -0.621948  0.218021 -1.131895  0.265820 -1.693620  0.784595  0.512051
# 7801  1.475640 -0.517951  1.248332  1.320089  1.040156 -1.890626 -0.724290
# 7802 -0.090312  0.220953 -1.009286  0.459197 -1.645672  0.853884  0.699640
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,15))
sns.heatmap(pca_data .corr(),annot=True, cmap="Reds",linewidth=0.5)
plt.show()

# %%
corr =pca_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f4720_row0_col0, #T_f4720_row1_col1, #T_f4720_row2_col2, #T_f4720_row3_col3, #T_f4720_row4_col4, #T_f4720_row5_col5, #T_f4720_row6_col6, #T_f4720_row7_col7, #T_f4720_row8_col8, #T_f4720_row9_col9, #T_f4720_row10_col10, #T_f4720_row11_col11, #T_f4720_row12_col12, #T_f4720_row13_col13, #T_f4720_row14_col14, #T_f4720_row15_col15, #T_f4720_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# Train Test Split - pca_data

# %%
Xp = pca_data
Yp = data['koi_pdisposition']
X_trainp, X_testp, Y_trainp, Y_testp = train_test_split(Xp, Yp, test_size = 0.25)

# %%
print("Trainp Shape",X_trainp.shape)
print("Testp Shape",X_testp.shape)
# Out:
# Trainp Shape (5852, 17)
# Testp Shape (1951, 17)

# %% [markdown]
# Logistic Regression model using principle component data

# %%
from sklearn.linear_model import LogisticRegression
#model= LogisticRegression(solver='lbfgs')
modelp = LogisticRegression()
modelp.fit(X_trainp, Y_trainp)
# Out:
# LogisticRegression()

# %%
predictionp=modelp.predict(X_testp)
predictionp
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %%
Logi_accp=metrics.accuracy_score(predictionp,Y_testp)*100
print('The accuracy of the LogisticRegression is',round(Logi_accp,2))
# Out:
# The accuracy of the LogisticRegression is 96.26

# %%
from sklearn.metrics import confusion_matrix
cmp= confusion_matrix(Y_testp,predictionp)
print(cmp)
# Out:
# [[972  41]
#  [ 32 906]]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ax=plt.axes()
pca_data_cm=cmp
sns.heatmap(pca_data_cm,annot=True,annot_kws={"size": 30}, fmt='d',cmap="Blues", ax = ax )
ax.set_title('Confusion Matrix')
plt.show()

# %% [markdown]
# Decision Tree model using principle component data

# %%
from sklearn.tree import DecisionTreeClassifier
mymodelp=DecisionTreeClassifier()
mymodelp.fit(X_trainp,Y_trainp)
# Out:
# DecisionTreeClassifier()

# %%
predictionp=mymodelp.predict(X_testp)
predictionp
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %%
Dec_accp=metrics.accuracy_score(predictionp,Y_testp)*100
print('The accuracy of the Decision Tree is',round(Dec_accp,2))
# Out:
# The accuracy of the Decision Tree is 93.8

# %% [markdown]
# KNeighborsClassifier using pca_data

# %%
import numpy as np
error_rate = []
for i in range(1,80):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_trainp,Y_trainp)
    pred_i = knn.predict(X_testp)
    error_rate.append(np.mean(pred_i != Y_test))

plt.figure(figsize=(5,15))
plt.plot(range(1,80),error_rate,color='blue', linestyle='dashed',
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
print("Minimum error:-",min(error_rate),"at K =",error_rate.index(min(error_rate)))
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...
